# %%
import pandas as pd
import numpy as np
import yfinance as yf
from datetime import datetime
import math
import os
import random
import torch
import warnings
warnings.filterwarnings('ignore')

# %%
seed = 42
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
np.random.seed(seed)
random.seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # Download Data From Yahoo Finance
# ----
# * XLE: Energy from 1998/12/16
#
# * XLU: Utilities from 1998/12/16
#
# * XLK: Technology from 1998/12/16
#
# * XLB: Materials from 1998/12/16
#
# * XLP: Consumer Staples from 1998/12/16
#
# * XLY: Consumer Discretionary from 1998/12/16
#
# * XLI: Industrial from 1998/12/16
#
# * XLV: Health Care from 1998/12/16
#
# * XLF: Financials from 1998/12/16
#
# * XLRE: Real Estates from 2015/10/17
#
# * XLC: Communication Services from 2018/06/18

# %%
def get_historical_Data(ticker, start, end):
    start_date = datetime.strptime(start, '%Y-%m-%d')
    end_date = datetime.strptime(end, '%Y-%m-%d')
    data = pd.DataFrame()
    for j in range(6):
        data = pd.concat([data, pd.DataFrame(yf.download(ticker, start=start_date, 
                                                         end=end_date).iloc[:, j])], axis=1)
        
    data['name'] = ticker
    data = data[['name', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume']]
    return data

def download_data(ticker_list, start, end):
    data = pd.DataFrame()
    
    for ticker in ticker_list:
        new = get_historical_Data(ticker, start, end)
        data = pd.concat([data, new], axis = 0)
        
    return data

# %%
ticker_list = ['XLE', 'XLU', 'XLK', 'XLB', 'XLP', 'XLY', 'XLI', 'XLV', 'XLF']

data = download_data(ticker_list, '1998-12-16', '2022-12-31')

data['log_hl'] = np.log((data['High'] / data['Low'])+1e-5)
data['log_co'] = np.log((data['Close'] / data['Open'])+1e-5)
data['Adj_Close_pct_change'] = data.groupby('name')['Adj Close'].pct_change()
data['log_volume'] = np.log(data['Volume']+1e-5)
data = data[['name','Adj_Close_pct_change', 'log_volume', 'log_co', 'log_hl']]
data.dropna(inplace = True)
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#            name  Adj_Close_pct_change  log_volume    log_co    log_hl
# Date
# 1998-12-23  XLE              0.020820   11.124317  0.017263  0.018603
# 1998-12-24  XLE             -0.005263    9.417355 -0.007895  0.009239
# 1998-12-28  XLE             -0.005292    9.510445 -0.010572  0.017263
# 1998-12-29  XLE              0.009973    9.998798  0.007278  0.016605
# 1998-12-30  XLE             -0.015140    9.989665 -0.014589  0.015277
# ...         ...                   ...         ...       ...       ...
# 2022-12-23  XLF              0.005628   16.655536  0.006215  0.012738
# 2022-12-27  XLF             -0.000295   17.058146 -0.002344  0.008846
# 2022-12-28  XLF             -0.003536   17.009893 -0.005298  0.009145
# 2022-12-29  XLF              0.013897   17.097331  0.008503  0.012607
# 2022-12-30  XLF             -0.002625   17.023758  0.004699  0.010275
#
# [54405 rows x 5 columns]

# %% [markdown]
# # DataFrame to Torch

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(f"Device = {device}")
# Out:
# Device = cpu

# %%
X_list = []
y_list = []
#window size: w
w = 10

for ticker in ticker_list:
    df = data[data['name'] == ticker][['Adj_Close_pct_change', 'log_volume', 'log_co', 'log_hl']]
    features = torch.tensor(df.values.astype(np.float32))
    label = torch.tensor(df['Adj_Close_pct_change'].values.astype(np.float32))
    X = features.unfold(0, w, 1)[:-1].to(torch.float32).to(device)
    Y = label[w:].to(torch.float32).to(device)
    X_list.append(X)
    y_list.append(Y)
    
X = torch.stack(X_list).transpose(0, 1)
y = torch.stack(y_list).transpose(0, 1)

X.shape, y.shape
# Out:
# (torch.Size([6035, 9, 4, 10]), torch.Size([6035, 9]))

# %% [markdown]
# # Split Data
#
# Train: 70%
#
# Valid: 15%
#
# Test: 15%

# %%
from sklearn.model_selection import train_test_split

X_train, X_rem, y_train, y_rem = train_test_split(X, y, 
                                                  test_size=0.3,
                                                  shuffle = False)
X_valid, X_test, y_valid, y_test = train_test_split(X_rem, y_rem, 
                                                    test_size=0.5,
                                                    shuffle = False)

len(X_train), len(X_valid),len(X_test), len(y_train), len(y_valid), len(y_test)
# Out:
# (4224, 905, 906, 4224, 905, 906)

# %% [markdown]
# # Data Loader

# %%
from torch.utils.data import TensorDataset, DataLoader

#Put Features and Labels Together
train_data = TensorDataset(X_train, y_train)
valid_data = TensorDataset(X_valid, y_valid)
test_data = TensorDataset(X_test, y_test)

# Setup the batch size hyperparameter
BATCH_SIZE = 64
# Turn datasets into iterables (batches)
train_dataloader = DataLoader(train_data, # dataset to turn into iterable
    batch_size=BATCH_SIZE, # how many samples per batch? 
    shuffle=False# shuffle data every epoch?
)

valid_dataloader = DataLoader(valid_data,
    batch_size=BATCH_SIZE,
    shuffle=False
)

# %%
first_batch = next(iter(train_dataloader))[0]
first_batch.shape
# Out:
# torch.Size([64, 9, 4, 10])

# %% [markdown]
# # Model

# %%
import torch.nn as nn

class GetLSTMOutput(nn.Module): #To Ignore the second output of LSTM Layer
    def forward(self, x):
        out, _ = x
        return out
    
class newmodel(nn.Module):
    def __init__(self):
        super().__init__()
        self.layers = nn.Sequential(
            nn.LayerNorm([10]),
            
            nn.Conv2d(in_channels=9, out_channels=16, kernel_size=(1, 5)),
            nn.MaxPool2d(kernel_size = (1, 3)),
            nn.ReLU(),
            
            nn.Flatten(),
            
            nn.LSTM(input_size=128, hidden_size=16, bidirectional=True, batch_first=True, dropout = 0.1),
            GetLSTMOutput(),
            nn.ReLU(),
            
            nn.Linear(32, 9),
            nn.Dropout(p = 0.1)
        )
        
    def forward(self, x):
        x = self.layers(x)
        return x

# %%
from torchinfo import summary
summary(newmodel(), input_size=first_batch.shape)
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# newmodel                                 [64, 9]                   --
# ├─Sequential: 1-1                        [64, 9]                   --
# │    └─LayerNorm: 2-1                    [64, 9, 4, 10]            20
# │    └─Conv2d: 2-2                       [64, 16, 4, 6]            736
# │    └─MaxPool2d: 2-3                    [64, 16, 4, 2]            --
# │    └─ReLU: 2-4                         [64, 16, 4, 2]            --
# │    └─Flatten: 2-5                      [64, 128]                 --
# │    └─LSTM: 2-6                         [64, 32]                  18,688
# │    └─GetLSTMOutput: 2-7                [64, 32]                  --
# │    └─ReLU: 2-8                         [64, 32]                  --
# │    └─Linear: 2-9                       [64, 9]                   297
# │    └─Dropout: 2-10                     [64, 9]                   --
# ==========================================================================================
# Total params: 19,741
# Trainable params: 19,741
# Non-trainable params: 0
# Total mult-adds (M): 39.42
# ==========================================================================================
# Input size (MB): 0.09
# Forward/backward pass size (MB): 0.40
# Params size (MB): 0.08
# Estimated Total Size (MB): 0.57
# ==========================================================================================

# %% [markdown]
# # Training Loop, Loss Function and Optimizer

# %%
from timeit import default_timer as timer 
def print_train_time(start: float, end: float, device: torch.device = None):
    """Prints difference between start and end time.

    Args:
        start (float): Start time of computation (preferred in timeit format). 
        end (float): End time of computation.
        device ([type], optional): Device that compute is running on. Defaults to None.

    Returns:
        float: time between start and end in seconds (higher is longer).
    """
    total_time = end - start
    print(f"Train time on {device}: {total_time:.3f} seconds")
    return total_time

# %%
torch.manual_seed(seed)
model = newmodel().to(device)
loss_fn = nn.HuberLoss(reduction = 'mean', delta = 1.0) #The Loss Function to train model
mse_loss = nn.MSELoss()
optimizer = torch.optim.RMSprop(model.parameters(), lr = 0.001, eps = 1e-8)

from tqdm.auto import tqdm
train_time_start_on_cpu = timer()

epochs = 100

best_loss = math.inf

if not os.path.isdir('./models'):
    os.mkdir('./models') # Create directory of saving models.
    
model_save_path = './models/SectorETFsmodel.ckpt'

# Create training and validating loop
for epoch in tqdm(range(epochs)):
    print(f"Epoch: {epoch}\n-------")
    ### Training
    train_loss = 0
    train_mse = 0
    # Add a loop to loop through training batches
    for batch, (X, y) in enumerate(train_dataloader):
        model.train() 
        # 1. Forward pass
        y_pred = model(X)

        # 2. Calculate loss (per batch)
        loss = loss_fn(y_pred, y)
        train_loss += loss # accumulatively add up the loss per epoch
        train_mse += mse_loss(y_pred, y)

        # 3. Optimizer zero grad
        optimizer.zero_grad()

        # 4. Loss backward
        loss.backward()

        # 5. Optimizer step
        optimizer.step()

        # Print out how many samples have been seen
        if batch % 40 == 0:
            print(f"Looked at {batch * len(X)}/{len(train_dataloader.dataset)} samples")

    # Divide total train loss by length of train dataloader (average loss per batch per epoch)
    train_loss /= len(train_dataloader)
    train_mse /= len(train_dataloader)
    
    ### Validating
    # Setup variables for accumulatively adding up loss and accuracy 
    valid_loss = 0 
    valid_mse = 0
    model.eval()
    with torch.inference_mode():
        for X, y in valid_dataloader:
            # 1. Forward pass
            valid_pred = model(X)
           
            # 2. Calculate loss (accumatively)
            valid_loss += loss_fn(valid_pred, y) # accumulatively add up the loss per epoch
            valid_mse += mse_loss(valid_pred, y)
        
        # Calculations on valid metrics need to happen inside torch.inference_mode()
        # Divide total valid loss by length of valid dataloader (per batch)
        valid_loss /= len(valid_dataloader)
        valid_mse /= len(valid_dataloader)

        if valid_loss < best_loss:
            best_loss = valid_loss
            torch.save(model.state_dict(), model_save_path) # Save your best model
            print('Saving model with loss {:.3f}...'.format(best_loss))
    ## Print out what's happening
    print(f"\nTrain loss: {train_loss:.7f} | Train mse: {train_mse:.7f} | Valid loss: {valid_loss:.7f} | Valid mse: {valid_mse:.7f}")

# Calculate training time      
train_time_end_on_cpu = timer()
total_train_time_model = print_train_time(start=train_time_start_on_cpu, 
                                           end=train_time_end_on_cpu,
                                           device=str(next(model.parameters()).device))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Epoch: 0
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0007169 | Train mse: 0.0014338 | Valid loss: 0.0001795 | Valid mse: 0.0003590
# Epoch: 1
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0002206 | Train mse: 0.0004411 | Valid loss: 0.0001217 | Valid mse: 0.0002434
# Epoch: 2
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001723 | Train mse: 0.0003445 | Valid loss: 0.0000944 | Valid mse: 0.0001887
# Epoch: 3
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001482 | Train mse: 0.0002964 | Valid loss: 0.0000794 | Valid mse: 0.0001588
# Epoch: 4
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001345 | Train mse: 0.0002691 | Valid loss: 0.0000705 | Valid mse: 0.0001410
# Epoch: 5
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001263 | Train mse: 0.0002527 | Valid loss: 0.0000649 | Valid mse: 0.0001299
# Epoch: 6
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001219 | Train mse: 0.0002438 | Valid loss: 0.0000614 | Valid mse: 0.0001227
# Epoch: 7
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001189 | Train mse: 0.0002378 | Valid loss: 0.0000587 | Valid mse: 0.0001174
# Epoch: 8
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001167 | Train mse: 0.0002334 | Valid loss: 0.0000571 | Valid mse: 0.0001141
# Epoch: 9
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001151 | Train mse: 0.0002302 | Valid loss: 0.0000568 | Valid mse: 0.0001136
# Epoch: 10
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001132 | Train mse: 0.0002264 | Valid loss: 0.0000554 | Valid mse: 0.0001109
# Epoch: 11
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001107 | Train mse: 0.0002213 | Valid loss: 0.0000518 | Valid mse: 0.0001036
# Epoch: 12
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001068 | Train mse: 0.0002136 | Valid loss: 0.0000502 | Valid mse: 0.0001004
# Epoch: 13
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001032 | Train mse: 0.0002064 | Valid loss: 0.0000481 | Valid mse: 0.0000963
# Epoch: 14
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0001001 | Train mse: 0.0002002 | Valid loss: 0.0000460 | Valid mse: 0.0000920
# Epoch: 15
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0000946 | Train mse: 0.0001892 | Valid loss: 0.0000435 | Valid mse: 0.0000869
# Epoch: 16
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0000921 | Train mse: 0.0001841 | Valid loss: 0.0000411 | Valid mse: 0.0000822
# Epoch: 17
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0000862 | Train mse: 0.0001724 | Valid loss: 0.0000384 | Valid mse: 0.0000769
# Epoch: 18
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000502 | Train mse: 0.0001005 | Valid loss: 0.0000272 | Valid mse: 0.0000544
# Epoch: 78
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000493 | Train mse: 0.0000986 | Valid loss: 0.0000277 | Valid mse: 0.0000554
# Epoch: 79
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0000497 | Train mse: 0.0000995 | Valid loss: 0.0000259 | Valid mse: 0.0000518
# Epoch: 80
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000493 | Train mse: 0.0000985 | Valid loss: 0.0000265 | Valid mse: 0.0000531
# Epoch: 81
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000518 | Train mse: 0.0001036 | Valid loss: 0.0000259 | Valid mse: 0.0000518
# Epoch: 82
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0000516 | Train mse: 0.0001032 | Valid loss: 0.0000255 | Valid mse: 0.0000510
# Epoch: 83
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000477 | Train mse: 0.0000954 | Valid loss: 0.0000261 | Valid mse: 0.0000521
# Epoch: 84
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000485 | Train mse: 0.0000970 | Valid loss: 0.0000272 | Valid mse: 0.0000544
# Epoch: 85
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000472 | Train mse: 0.0000944 | Valid loss: 0.0000268 | Valid mse: 0.0000535
# Epoch: 86
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000492 | Train mse: 0.0000984 | Valid loss: 0.0000264 | Valid mse: 0.0000528
# Epoch: 87
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000474 | Train mse: 0.0000948 | Valid loss: 0.0000270 | Valid mse: 0.0000539
# Epoch: 88
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000478 | Train mse: 0.0000957 | Valid loss: 0.0000256 | Valid mse: 0.0000511
# Epoch: 89
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000483 | Train mse: 0.0000965 | Valid loss: 0.0000261 | Valid mse: 0.0000521
# Epoch: 90
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000467 | Train mse: 0.0000934 | Valid loss: 0.0000262 | Valid mse: 0.0000524
# Epoch: 91
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000489 | Train mse: 0.0000977 | Valid loss: 0.0000263 | Valid mse: 0.0000527
# Epoch: 92
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000466 | Train mse: 0.0000932 | Valid loss: 0.0000262 | Valid mse: 0.0000524
# Epoch: 93
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000459 | Train mse: 0.0000919 | Valid loss: 0.0000264 | Valid mse: 0.0000528
# Epoch: 94
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000486 | Train mse: 0.0000973 | Valid loss: 0.0000263 | Valid mse: 0.0000525
# Epoch: 95
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000451 | Train mse: 0.0000901 | Valid loss: 0.0000262 | Valid mse: 0.0000525
# Epoch: 96
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000458 | Train mse: 0.0000916 | Valid loss: 0.0000261 | Valid mse: 0.0000522
# Epoch: 97
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
#
# Train loss: 0.0000451 | Train mse: 0.0000902 | Valid loss: 0.0000273 | Valid mse: 0.0000547
# Epoch: 98
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0000475 | Train mse: 0.0000949 | Valid loss: 0.0000253 | Valid mse: 0.0000507
# Epoch: 99
# -------
# Looked at 0/4224 samples
# Looked at 2560/4224 samples
# Saving model with loss 0.000...
#
# Train loss: 0.0000472 | Train mse: 0.0000944 | Valid loss: 0.0000251 | Valid mse: 0.0000501
# Train time on cpu: 34.296 seconds

# %% [markdown]
# # Test Set

# %%
#Load Trained Model
model_test = newmodel().to(device)
model_test.load_state_dict(torch.load(model_save_path))

model_test.eval()
with torch.inference_mode():
    test_pred = model_test(X_test)
    print(f'The MSE Loss on Test Set is: {mse_loss(test_pred, y_test):.7f}')
# Out:
# The MSE Loss on Test Set is: 0.0001517

# %%
pd.DataFrame(test_pred)
# Out:
#             0         1         2         3         4         5         6  \
# 0   -0.002322  0.006939  0.005827 -0.001680 -0.001129  0.004207  0.005791
# 1   -0.004478 -0.004440 -0.008384 -0.008147 -0.003563 -0.009165 -0.009781
# 2    0.024880  0.008206 -0.005537  0.017005  0.004153 -0.000366  0.005652
# 3    0.015095  0.010042  0.019022  0.017344  0.010497  0.018327  0.016932
# 4    0.000355  0.003578  0.011190  0.003645  0.003286  0.009235  0.007679
# ..        ...       ...       ...       ...       ...       ...       ...
# 901  0.012569  0.006315  0.003659  0.010804  0.004867  0.005477  0.006952
# 902  0.004317  0.003293 -0.002504  0.003888  0.000309 -0.000046  0.002296
# 903 -0.009044 -0.001076 -0.000533 -0.007740 -0.003269 -0.002066 -0.002773
# 904  0.010148  0.007075  0.011840  0.010631  0.006273  0.011177  0.010538
# 905  0.001045  0.002752  0.001400  0.001027 -0.000311  0.001445  0.002595
#
#             7         8
# 0    0.000458  0.007588
# 1   -0.008423 -0.008810
# 2    0.001078  0.000162
# 3    0.011504  0.022614
# 4    0.004479  0.011340
# ..        ...       ...
# 901  0.003325  0.006722
# 902 -0.000628 -0.000937
# 903 -0.003286 -0.004883
# 904  0.006672  0.012698
# 905  0.000024  0.000220
#
# [906 rows x 9 columns]

# %%
pred_val = pd.DataFrame(test_pred)
real_val = pd.DataFrame(y_test)

df = pred_val.melt(var_name='number', value_name='pred')
real_melted = real_val.melt(var_name='number', value_name='real')
df['real'] = real_melted['real'].values

ticker_dict = {0: 'XLE', 1: 'XLU', 2: 'XLK', 3: 'XLB', 4: 'XLP', 5: 'XLY', 6: 'XLI', 7: 'XLV', 8: 'XLF'}
df['ticker'] = df['number'].map(ticker_dict)

df
# Out:
#       number      pred      real ticker
# 0          0 -0.002322 -0.012708    XLE
# 1          0 -0.004478 -0.017552    XLE
# 2          0  0.024880  0.012761    XLE
# 3          0  0.015095  0.017305    XLE
# 4          0  0.000355 -0.011065    XLE
# ...      ...       ...       ...    ...
# 8149       8  0.006722  0.005628    XLF
# 8150       8 -0.000937 -0.000295    XLF
# 8151       8 -0.004883 -0.003536    XLF
# 8152       8  0.012698  0.013897    XLF
# 8153       8  0.000220 -0.002625    XLF
#
# [8154 rows x 4 columns]

# %%
for ticker in ticker_list:
    sub_df = df[df['number']==i]
    sub_df.index = data.loc[~data.index.duplicated(keep='first')][-len(y_test):].index
    
    plt.figure(figsize=(8, 8))
    pred = sub_df['pred'].values
    real = sub_df['real'].values
    plt.scatter(pred, real, s=8)
    # Add 45 degree line
    x = np.linspace(min(pred.min(), real.min()), max(pred.max(), real.max()), 100)
    plt.plot(x, x, color='red', linestyle='--', linewidth=1)
    # Add labels and title
    plt.xlabel('Predicted Values')
    plt.ylabel('Real Values')
    plt.title(f'Real Value and Predicted Value of Daily Return of {ticker_list[i]}')
    
    plt.figure(figsize=(15, 8))
    plt.plot(sub_df.index, (1+ sub_df['pred']).cumprod(), label='Predicted', linewidth=0.5)
    plt.plot(sub_df.index, (1+ sub_df['real']).cumprod(), label='Real', linewidth=0.5)
    plt.plot(sub_df.index, (sub_df['pred'] - sub_df['real'])*10, label='Predicted Daily Return - Real Daily Return * 10', linewidth=0.5)
    plt.legend()
    plt.xlabel('Time')
    plt.ylabel('Values')
    plt.title(f'{ticker_list[i]} Cumulative Return 2019-05-30 ~ 2022-12-30')
    plt.show()
